# %%
import pandas as pd
import numpy as np

# %%
# Load mega_merged
mega_merged = pd.read_csv("../finalized_datasets/mega_merged.csv")
mega_merged.head(60)
# Out:
#     Unnamed: 0                 State  Year  Population  \
# 0          122               Alabama  2014     4843737
# 1          164                Alaska  2014      737075
# 2           81               Arizona  2014     6732873
# 3           82               Arizona  2014     6732873
# 4           75            California  2014    38586706
# 5          219              Colorado  2014     5352637
# 6          232           Connecticut  2014     3595697
# 7          279              Delaware  2014      933131
# 8          191  District of Columbia  2014      663603
# 9          115               Florida  2014    19853880
# 10          62               Georgia  2014    10071204
# 11          68                Hawaii  2014     1415335
# 12         157                 Idaho  2014     1632248
# 13         108              Illinois  2014    12885092
# 14         245               Indiana  2014     6596019
# 15          28                  Iowa  2014     3110643
# ...

# %%
# Drop first column
mega_merged = mega_merged.drop(columns=["Unnamed: 0"])
mega_merged
# Out:
#                    State  Year  Population  Number of Cannabis Users  \
# 0                Alabama  2014     4843737                    404000
# 1                 Alaska  2014      737075                    114000
# 2                Arizona  2014     6732873                    752000
# 3                Arizona  2014     6732873                    752000
# 4             California  2014    38586706                   4633000
# 5               Colorado  2014     5352637                    909000
# 6            Connecticut  2014     3595697                    427000
# 7               Delaware  2014      933131                    109000
# 8   District of Columbia  2014      663603                    121000
# 9                Florida  2014    19853880                   1990000
# 10               Georgia  2014    10071204                    963000
# 11                Hawaii  2014     1415335                    144000
# 12                 Idaho  2014     1632248                    152000
# ...

# %%
# Load mega_merged
mega_merged = pd.read_csv("../finalized_datasets/mega_merged.csv")
mega_merged.head()
# Out:
#    Unnamed: 0       State  Year  Population  Number of Cannabis Users  \
# 0         122     Alabama  2014     4843737                    404000
# 1         164      Alaska  2014      737075                    114000
# 2          81     Arizona  2014     6732873                    752000
# 3          82     Arizona  2014     6732873                    752000
# 4          75  California  2014    38586706                   4633000
#
#    Number of Opioid Deaths  Per Capita Cannabis Use  Per Capita Opioid Deaths  \
# 0                      723                 0.083407                  0.000149
# 1                      124                 0.154665                  0.000168
# 2                      356                 0.111691                  0.000053
# 3                     1211                 0.111691                  0.000180
# 4                     4521                 0.120067                  0.000117
#
#    Recreational  Rec Year Legalized  Medical  Med Year Legalized  \
# ...
